# %%
from rag_model_wrap import build_and_save_rag
build_and_save_rag()
# Out:
# 📥 Loading dataset...
# 🔧 Preprocessing...
# 🧠 Loading embedder (MiniLM)...
# ⚙️ Encoding recipes (this takes time)...
# Batches:   0%|          | 0/7239 [00:00<?, ?it/s]
# 🔎 Building nearest neighbors index...
# 💾 Saving artifacts...
# ✅ DONE — RAG model saved to 'rag_artifacts/'
